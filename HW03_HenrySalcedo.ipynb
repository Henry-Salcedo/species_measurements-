# %%
import pandas as pd
import math
import numpy as np
# Imported packages/modules.

# %%
# Read CSVs and drop the extra index column saved in the files.
petal_df = pd.read_csv("Petal_Data.csv", index_col=0)
sepal_df = pd.read_csv("Sepal_Data.csv", index_col=0)
sepal_df.head()
# Loading in the csv files and displaying the head of either to review the data.
# Out:
#          sample_id     species  sepal_length  sepal_width
# 0  kzkn5q6TioixrLl   virginica      6.478159     3.035585
# 1  YkBvRsNxkaMuaqN  versicolor      5.520372     3.006424
# 2  RCpoVUsSf1lcnsx   virginica      5.609393     3.173603
# 3  bRJfblUTBih4vXZ   virginica      7.042214     2.808181
# 4  7eMPKj06G5OvZMj   virginica      6.996548     3.022570

# %%
# Quick column check to diagnose KeyError issues.
print("Petal columns:", petal_df.columns.tolist())
print("Sepal columns:", sepal_df.columns.tolist())
# Out:
# Petal columns: ['sample_id', 'species', 'petal_length', 'petal_width']
# Sepal columns: ['sample_id', 'species', 'sepal_length', 'sepal_width']

# %%
# Combine into a single dataframe for the specific columns.
combined_df = pd.merge(
    petal_df,
    sepal_df.drop(columns=["species"]),
    on="sample_id",
    how="inner",
)
combined_df = combined_df[[
    "sample_id",
    "species",
    "petal_length",
    "petal_width",
    "sepal_length",
    "sepal_width",
]]

combined_df.head(10)
# Out:
#          sample_id     species  petal_length  petal_width  sepal_length  \
# 0  g4JZlAtiN4mBGyE  versicolor      4.589243     1.306969      5.844006
# 1  BwWealRi00L4RH1  versicolor      4.836183     1.384244      5.919572
# 2  ZdyiDoTAArjRj3X   virginica      5.510280     1.786967      6.081146
# 3  0NqN8AaLZ8jelu^      setosa      1.434607     0.419694      4.036309
# 4  8nqRlCsXKJjHafD  versicolor      3.950310     1.224275      6.885232
# 5  otVBvvcynjp7UzN      setosa      1.506729     0.325962      5.401327
# 6  fWIrmBqHQtz8xsF   virginica      5.604368     2.157243      6.456809
# 7  ARwpVhHYWHt9wfY      setosa      1.614061     0.199143      4.903286
# 8  F5F0rlPyu#7r6qZ      setosa      1.702897     0.095686      5.192556
# 9  yi19vtGTuYKj4eZ  versicolor      4.268392     1.274064      6.822197
#
#    sepal_width
# 0     3.341825
# 1     2.624173
# 2     3.040232
# 3     3.527450
# 4     3.631972
# 5     3.720574
# 6     2.805747
# 7     3.145444
# 8     3.526238
# 9     3.141830

# %%
# Used to see the 3 unique species names that are used.
combined_df['species'].unique()
# Out:
# array(['versicolor', 'virginica', 'setosa'], dtype=object)

# %%
# Correlation matrices for each species (numeric columns only).
numeric_cols = ["petal_length", "petal_width", "sepal_length", "sepal_width"]
corr_by_species = combined_df.groupby("species")[numeric_cols].corr()
corr_by_species
# Out:
#                          petal_length  petal_width  sepal_length  sepal_width
# species
# setosa     petal_length      1.000000     0.219993     -0.003592    -0.290102
#            petal_width       0.219993     1.000000      0.091356     0.036456
#            sepal_length     -0.003592     0.091356      1.000000     0.117963
#            sepal_width      -0.290102     0.036456      0.117963     1.000000
# versicolor petal_length      1.000000    -0.241938      0.007745    -0.063534
#            petal_width      -0.241938     1.000000     -0.021792     0.069380
#            sepal_length      0.007745    -0.021792      1.000000     0.155452
#            sepal_width      -0.063534     0.069380      0.155452     1.000000
# virginica  petal_length      1.000000     0.291776     -0.024689     0.027446
#            petal_width       0.291776     1.000000     -0.116856     0.042958
#            sepal_length     -0.024689    -0.116856      1.000000    -0.527611
#            sepal_width       0.027446     0.042958     -0.527611     1.000000

# %%
# Average of each variable by species.
avg_cols = ["petal_length", "petal_width", "sepal_length", "sepal_width"]
avg_by_species = combined_df.groupby("species")[avg_cols].mean()
avg_by_species
# Out:
#             petal_length  petal_width  sepal_length  sepal_width
# species
# setosa          1.486527     0.250725      4.999635     3.475225
# versicolor      4.290690     1.345846      5.942616     2.761610
# virginica       5.475172     1.988239      6.354953     3.001511

# %%
# Median of each variable by species.
med_cols = ["petal_length", "petal_width", "sepal_length", "sepal_width"]
med_by_species = combined_df.groupby("species")[med_cols].median()
med_by_species
# Out:
#             petal_length  petal_width  sepal_length  sepal_width
# species
# setosa          1.464998     0.251564      4.977019     3.460304
# versicolor      4.321910     1.372359      5.917317     2.747044
# virginica       5.512922     1.954197      6.277034     3.019348

# %%
# Standard Deviation (std) of each variable by species.
std_cols = ["petal_length", "petal_width", "sepal_length", "sepal_width"]
std_by_species = combined_df.groupby("species")[std_cols].std()
std_by_species
# Out:
#             petal_length  petal_width  sepal_length  sepal_width
# species
# setosa          0.207064     0.116201      0.323130     0.365322
# versicolor      0.465222     0.185877      0.475391     0.385754
# virginica       0.458861     0.242253      0.573233     0.325909
